# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../Results/Data/before_encode.csv")
df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches      none      none      none      none      none
# 1                  none      none      none      none      none      none
# 2                  none      none      none      none      none      none
# 3                  none      none      none      none      none      none
# 4                  none      none      none      none      none      none
#
# ...

# %%
group = df.groupby(df['Disease']).count()

# %%
Symptom_1 = set(df['Symptom_1'].unique())
Symptom_2 = set(df['Symptom_2'].unique())
Symptom_3 = set(df['Symptom_3'].unique())
Symptom_4 = set(df['Symptom_4'].unique())
Symptom_5 = set(df['Symptom_5'].unique())
Symptom_6 = set(df['Symptom_6'].unique())
Symptom_7 = set(df['Symptom_7'].unique())
Symptom_8 = set(df['Symptom_8'].unique())
Symptom_9 = set(df['Symptom_9'].unique())
Symptom_10 = set(df['Symptom_10'].unique())
Symptom_11 = set(df['Symptom_11'].unique())
Symptom_12 = set(df['Symptom_12'].unique())
Symptom_13 = set(df['Symptom_13'].unique())
Symptom_14 = set(df['Symptom_14'].unique())
Symptom_15 = set(df['Symptom_15'].unique())
Symptom_16 = set(df['Symptom_16'].unique())
Symptom_17 = set(df['Symptom_17'].unique())
print(Symptom_1.union(Symptom_2, Symptom_3, Symptom_4, Symptom_5, Symptom_6, Symptom_7, Symptom_8, Symptom_9, Symptom_10, Symptom_11, Symptom_12, Symptom_13, Symptom_14, Symptom_15, Symptom_16, Symptom_17))
all_symptoms = Symptom_1.union(Symptom_2, Symptom_3, Symptom_4, Symptom_5, Symptom_6, Symptom_7, Symptom_8, Symptom_9, Symptom_10, Symptom_11, Symptom_12, Symptom_13, Symptom_14, Symptom_15, Symptom_16, Symptom_17)
# Out:
# {' skin_peeling', ' back_pain', ' neck_pain', ' receiving_blood_transfusion', ' cramps', ' loss_of_appetite', ' weight_gain', ' abnormal_menstruation', ' joint_pain', ' coma', ' inflammatory_nails', ' family_history', ' loss_of_smell', ' fast_heart_rate', ' rusty_sputum', ' continuous_sneezing', ' swelled_lymph_nodes', ' malaise', ' depression', ' pain_during_bowel_movements', ' weight_loss', ' swollen_extremeties', ' pus_filled_pimples', ' weakness_of_one_body_side', ' acute_liver_failure', ' skin_rash', ' lack_of_concentration', ' abdominal_pain', ' yellowing_of_eyes', ' yellowish_skin', ' watering_from_eyes', ' indigestion', ' yellow_crust_ooze', ' vomiting', ' yellow_urine', ' muscle_weakness', ' dizziness', ' sinus_pressure', ' stiff_neck', ' dehydration', ' fluid_overload', ' blood_in_sputum', ' anxiety', ' muscle_pain', ' blurred_and_distorted_vision', 'none', ' fatigue', ' muscle_wasting', ' extra_marital_contacts', ' phlegm', ' obesity', ' visual_disturbances', ' bladder_dis
# ...

# %%
print("Unique Symptoms:", all_symptoms)
# Out:
# Unique Symptoms: {' skin_peeling', ' back_pain', ' neck_pain', ' receiving_blood_transfusion', ' cramps', ' loss_of_appetite', ' weight_gain', ' abnormal_menstruation', ' joint_pain', ' coma', ' inflammatory_nails', ' family_history', ' loss_of_smell', ' fast_heart_rate', ' rusty_sputum', ' continuous_sneezing', ' swelled_lymph_nodes', ' malaise', ' depression', ' pain_during_bowel_movements', ' weight_loss', ' swollen_extremeties', ' pus_filled_pimples', ' weakness_of_one_body_side', ' acute_liver_failure', ' skin_rash', ' lack_of_concentration', ' abdominal_pain', ' yellowing_of_eyes', ' yellowish_skin', ' watering_from_eyes', ' indigestion', ' yellow_crust_ooze', ' vomiting', ' yellow_urine', ' muscle_weakness', ' dizziness', ' sinus_pressure', ' stiff_neck', ' dehydration', ' fluid_overload', ' blood_in_sputum', ' anxiety', ' muscle_pain', ' blurred_and_distorted_vision', 'none', ' fatigue', ' muscle_wasting', ' extra_marital_contacts', ' phlegm', ' obesity', ' visual_disturbance
# ...

# %%
for i in range(1, 18):
    print(f"Unique values in Symptom_{i}:", df[f'Symptom_{i}'].unique())
# Out:
# Unique values in Symptom_1: ['itching' ' skin_rash' ' continuous_sneezing' ' shivering'
#  ' stomach_pain' ' acidity' ' vomiting' ' indigestion' ' muscle_wasting'
#  ' patches_in_throat' ' fatigue' ' weight_loss' ' sunken_eyes' ' cough'
#  ' headache' ' chest_pain' ' back_pain' ' weakness_in_limbs' ' chills'
#  ' joint_pain' ' yellowish_skin' ' constipation'
#  ' pain_during_bowel_movements' ' breathlessness' ' cramps' ' weight_gain'
#  ' mood_swings' ' neck_pain' ' muscle_weakness' ' stiff_neck'
#  ' pus_filled_pimples' ' burning_micturition' ' bladder_discomfort'
#  ' high_fever']
# Unique values in Symptom_2: [' skin_rash' ' nodal_skin_eruptions' ' shivering' ' chills' ' acidity'
#  ' ulcers_on_tongue' ' vomiting' ' yellowish_skin' ' stomach_pain'
#  ' loss_of_appetite' ' indigestion' ' patches_in_throat' ' high_fever'
#  ' weight_loss' ' restlessness' ' sunken_eyes' ' dehydration' ' cough'
#  ' chest_pain' ' dizziness' ' headache' ' weakness_in_limbs' ' neck_pain'
# ...

# %%
le = LabelEncoder()

# %%
print(len(all_symptoms))
# Out:
# 132

# %%
all_symptoms = sorted(all_symptoms)  
le.fit(all_symptoms)
# Out:
# LabelEncoder()

# %%
print(all_symptoms)
# Out:
# [' abdominal_pain', ' abnormal_menstruation', ' acidity', ' acute_liver_failure', ' altered_sensorium', ' anxiety', ' back_pain', ' belly_pain', ' blackheads', ' bladder_discomfort', ' blister', ' blood_in_sputum', ' bloody_stool', ' blurred_and_distorted_vision', ' breathlessness', ' brittle_nails', ' bruising', ' burning_micturition', ' chest_pain', ' chills', ' cold_hands_and_feets', ' coma', ' congestion', ' constipation', ' continuous_feel_of_urine', ' continuous_sneezing', ' cough', ' cramps', ' dark_urine', ' dehydration', ' depression', ' diarrhoea', ' dischromic _patches', ' distention_of_abdomen', ' dizziness', ' drying_and_tingling_lips', ' enlarged_thyroid', ' excessive_hunger', ' extra_marital_contacts', ' family_history', ' fast_heart_rate', ' fatigue', ' fluid_overload', ' foul_smell_of urine', ' headache', ' high_fever', ' hip_joint_pain', ' history_of_alcohol_consumption', ' increased_appetite', ' indigestion', ' inflammatory_nails', ' internal_itching', ' irregular_
# ...

# %%
for col in df.columns:
    if 'Symptom' in col:
        df[col] = df[col].map(lambda x: le.transform([x])[0])
# df.head() 
# for col in df.columns:
#     df[col] = le.fit_transform(df[col])
# for col in df.columns:
#     df[col] = df[col].apply(lambda x: -1 if x is None else le.fit_transform([x])[0])

# %%
df.head()
# Out:
#             Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 0  Fungal infection        130         99         72         32        131
# 1  Fungal infection         99         72         32        131        131
# 2  Fungal infection        130         72         32        131        131
# 3  Fungal infection        130         99         32        131        131
# 4  Fungal infection        130         99         72        131        131
#
#    Symptom_6  Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  \
# 0        131        131        131        131         131         131
# 1        131        131        131        131         131         131
# 2        131        131        131        131         131         131
# 3        131        131        131        131         131         131
# 4        131        131        131        131         131         131
#
#    Symptom_12  Symptom_13  Symptom_14  Symptom_15  Symptom_16  Symptom_17
# ...

# %%
# Encode Disease column (if it exists)
if 'Disease' in df.columns:
    # Fit the encoder on the entire column, then transform
    df['Disease'] = le.fit_transform(df['Disease'])

# %%
print(df)
# Out:
#      Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 0         15        130         99         72         32        131
# 1         15         99         72         32        131        131
# 2         15        130         72         32        131        131
# 3         15        130         99         32        131        131
# 4         15        130         99         72        131        131
# ..       ...        ...        ...        ...        ...        ...
# 299       27         45         10         88        126        131
# 300       27         99         10         88        126        131
# 301       27         99         45         88        126        131
# 302       27         99         45         10        126        131
# 303       27         99         45         10         88        131
#
#      Symptom_6  Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  \
# 0          131        131        131        131         131         131
# ...

# %%
df['Disease'].unique()
df['Symptom_1'].unique()
# Out:
# array([130,  99,  25,  95, 106,   2, 120,  49,  68,  80,  41, 125, 107,
#         26,  44,  18,   6, 122,  19,  55, 129,  23,  75,  14,  27, 124,
#         64,  71,  69, 104,  85,  17,   9,  45])

# %%
df.head()
# Out:
#    Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  Symptom_6  \
# 0       15        130         99         72         32        131        131
# 1       15         99         72         32        131        131        131
# 2       15        130         72         32        131        131        131
# 3       15        130         99         32        131        131        131
# 4       15        130         99         72        131        131        131
#
#    Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  Symptom_12  \
# 0        131        131        131         131         131         131
# 1        131        131        131         131         131         131
# 2        131        131        131         131         131         131
# 3        131        131        131         131         131         131
# 4        131        131        131         131         131         131
#
#    Symptom_13  Symptom_14  Symptom_15  Symptom_16  Symptom_17
# ...

# %%
# df.to_csv('../Results/Data/encode_data.csv', index=False)
