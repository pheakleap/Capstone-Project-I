# %% [markdown]
# Logistic Regression Model Predictions

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
import joblib
import ast

# Load the trained model
model_file_path = r"D:\CADT University\CADT-Y3\CodeAllSub\Capstone\Capstone-Project-I\notebooks\Leab_notebooks\Models\logistic_regression_model.pkl"
model = joblib.load(model_file_path)

# Load the LabelEncoder and StandardScaler
label_encoder_file_path = r"D:\CADT University\CADT-Y3\CodeAllSub\Capstone\Capstone-Project-I\notebooks\Leab_notebooks\Models\label_encoder.pkl"
label_encoder = joblib.load(label_encoder_file_path)
scaler_file_path = r"D:\CADT University\CADT-Y3\CodeAllSub\Capstone\Capstone-Project-I\notebooks\Leab_notebooks\Models\scaler.pkl"
scaler = joblib.load(scaler_file_path)

# %%
# Ensure the LabelEncoder is fitted with all possible labels
unique_symptoms = [
    'abdominal_pain', 'abnormal_menstruation', 'acidity', 'acute_liver_failure', 'anxiety', 
    'back_pain', 'belly_pain', 'blurred_and_distorted_vision', 'breathlessness', 'brittle_nails', 
    'chest_pain', 'chills', 'cold_hands_and_feets', 'coma', 'congestion', 'constipation', 'continuous_sneezing', 
    'cough', 'dark_urine', 'depression', 'diarrhoea', 'dizziness', 'drying_and_tingling_lips', 'enlarged_thyroid', 
    'excessive_hunger', 'fast_heart_rate', 'fatigue', 'headache', 'high_fever', 'indigestion', 'irritability', 
    'joint_pain', 'lethargy', 'loss_of_appetite', 'loss_of_smell', 'malaise', 'mild_fever', 'mood_swings', 
    'muscle_pain', 'muscle_weakness', 'nausea', 'pain_behind_the_eyes', 'palpitations', 'phlegm', 'puffy_face_and_eyes', 
    'receiving_blood_transfusion', 'receiving_unsterile_injections', 'red_spots_over_body', 'redness_of_eyes', 
    'restlessness', 'runny_nose', 'rusty_sputum', 'sinus_pressure', 'skin_rash', 'slurred_speech', 'stiff_neck', 
    'stomach_bleeding', 'sweating', 'swelled_lymph_nodes', 'swollen_extremeties', 'throat_irritation', 'toxic_look_(typhos)', 
    'visual_disturbances', 'vomiting', 'weight_gain', 'weight_loss', 'yellow_urine', 'yellowing_of_eyes', 'yellowish_skin', 'itching',
    'irregular_sugar_level'  # Add any new symptoms here
]

label_encoder.fit(unique_symptoms + ['-1'])
# Out:
# LabelEncoder()

# %%
def predict_disease(input_symptoms):
    # Remove leading/trailing spaces and single quotes from each symptom
    input_symptoms = [symptom.strip().strip("'") for symptom in input_symptoms]
    
    # Create a DataFrame with one row and 17 columns, filling with '-1' for missing values
    input_df = pd.DataFrame([input_symptoms + ['-1'] * (17 - len(input_symptoms))], columns=symptoms_columns)
    
    # Convert all symptom columns to strings
    input_df[symptoms_columns] = input_df[symptoms_columns].astype(str)
    
    # Encode the symptom columns using the same LabelEncoder
    for col in symptoms_columns:
        mask = input_df[col] != '-1'  # Mask for "-1" values
        input_df.loc[mask, col] = label_encoder.transform(input_df.loc[mask, col])  # Encode the values that are not "-1"
        input_df.loc[~mask, col] = -1  # Replace the "-1" values back to "-1"
    
    # Convert the encoded data to integers
    input_df[symptoms_columns] = input_df[symptoms_columns].astype(int)
    
    # Scale the features using the same scaler
    input_df[symptoms_columns] = scaler.transform(input_df[symptoms_columns])
    
    # Predict the disease for the input symptoms
    predicted_disease_encoded = model.predict(input_df[symptoms_columns])
    
    # Map the encoded prediction back to the original disease label
    predicted_disease = label_encoder.inverse_transform(predicted_disease_encoded)
    
    # Display the predicted disease
    print(f"Predicted Disease: {predicted_disease[0]}")

# %%
# Prompt the user to input symptoms
input_symptoms = input("Enter symptoms separated by commas: ").split(',')

# Strip any leading/trailing whitespace and single quotes from each symptom
input_symptoms = [symptom.strip().strip("'") for symptom in input_symptoms]

# Ensure the input symptoms list has at most 17 symptoms
input_symptoms = input_symptoms[:17]

# Predict the disease based on the manually input symptoms
predict_disease(input_symptoms)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Downlaod\APPLICATION\Anaconda\App_File\envs\condaEnv\Lib\site-packages\sklearn\utils\_encode.py:235, in _encode(values, uniques, check_unknown)
#     234 try:
# --> 235     return _map_to_integer(values, uniques)
#     236 except KeyError as e:
#
# File d:\Downlaod\APPLICATION\Anaconda\App_File\envs\condaEnv\Lib\site-packages\sklearn\utils\_encode.py:174, in _map_to_integer(values, uniques)
#     173 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 174 return xp.asarray([table[v] for v in values], device=device(values))
#
# File d:\Downlaod\APPLICATION\Anaconda\App_File\envs\condaEnv\Lib\site-packages\sklearn\utils\_encode.py:167, in _nandict.__missing__(self, key)
#     166     return self.nan_value
# --> 167 raise KeyError(key)
#
# KeyError: 'obesity'
#
# ...
