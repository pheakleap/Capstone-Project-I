# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load the encoded data
file_path = 'c:/Users/LENOVO/OneDrive - Cambodia Academy of Digital Technology/Documents/Year 03/Year3 Term2/Cap Stone/Capstone-Project-I/data/processed/Cleaned_label_encoded.csv'
diseases_df = pd.read_csv(file_path)

# %%
# Define features and target
symptom_columns = [col for col in diseases_df.columns if "Symptom_" in col]
X = diseases_df[symptom_columns]  # Encoded symptoms as features
y = diseases_df["Disease_Encoded"]  # Encoded disease as target

# Split data into train (80%) and test (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# # Train the Random Forest classifier
# rf_classifier = RandomForestClassifier(n_estimators=100, class_weight='balanced',random_state=42)
# rf_classifier.fit(X_train, y_train)

# # Make predictions
# y_pred = rf_classifier.predict(X_test)

# # Evaluate the model
# accuracy = accuracy_score(y_test, y_pred)
# report = classification_report(y_test, y_pred)

# print(f"Accuracy: {accuracy}")
# print("Classification Report:")
# print(report)

# # Display train-test split details
# X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       1.00      1.00      1.00        36
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00        36
#            4       1.00      1.00      1.00        36
#            5       1.00      1.00      1.00        36
#            6       1.00      1.00      1.00        36
#            7       1.00      1.00      1.00        36
#            8       1.00      1.00      1.00        36
#            9       1.00      1.00      1.00        36
#           10       1.00      1.00      1.00        36
#           11       1.00      1.00      1.00        36
#
#     accuracy                           1.00       432
#    macro avg       1.00      1.00      1.00       432
# weighted avg       1.00      1.00      1.00       432
# ((1008, 18), (432, 18), (1008,), (432,))

# %%
# Define features and target
symptom_columns = [col for col in diseases_df.columns if "Symptom_" in col]
X = diseases_df[symptom_columns]  # Encoded symptoms as features
y = diseases_df["Disease_Encoded"]  # Encoded disease as target

# Split data into train (80%) and test (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Train the Random Forest classifier with cross-validation
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
cv_scores = cross_val_score(rf_classifier, X_train, y_train, cv=5)

print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {cv_scores.mean()}")

# Fit the model on the training data
rf_classifier.fit(X_train, y_train)

# Make predictions
y_pred = rf_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)

# Display feature importance
feature_importances = rf_classifier.feature_importances_
plt.figure(figsize=(10, 6))
plt.barh(symptom_columns, feature_importances)
plt.xlabel('Feature Importance')
plt.ylabel('Symptom')
plt.title('Feature Importance in Random Forest Classifier')
plt.show()
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean cross-validation score: 1.0
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       1.00      1.00      1.00        36
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00        36
#            4       1.00      1.00      1.00        36
#            5       1.00      1.00      1.00        36
#            6       1.00      1.00      1.00        36
#            7       1.00      1.00      1.00        36
#            8       1.00      1.00      1.00        36
#            9       1.00      1.00      1.00        36
#           10       1.00      1.00      1.00        36
#           11       1.00      1.00      1.00        36
#
#     accuracy                           1.00       432
#    macro avg       1.00      1.00      1.00       432
# ...
